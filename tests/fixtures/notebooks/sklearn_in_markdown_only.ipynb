# %% [markdown]
# # We should use sklearn and train_test_split with stratify=y and random_state=42
# # Also Pipeline( is great for preventing data leakage

# %%
import numpy as np
print('hello world')
